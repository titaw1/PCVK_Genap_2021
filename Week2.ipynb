# %% [markdown]
# <a href="https://colab.research.google.com/github/titaw1/PCVK_Genap_2022/blob/main/Week2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

# Accessing My Google Drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img, cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img, cv.COLOR_BGR2RGB), (512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB), 0)

#simpan file image
#cv.imwrite('/content/drive/MyDrive/PCVK_MM/Images/mandrill2.tiff', img5)

#tampilkan plot dengan ukuran canvas yang lebi besar
fig = plt.figure(figsize=(10,10)) #ubah-ubah ukuran (10,10) sesuai kebutuhan
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
#perhatikan koordinat titik2 pt1 dan pt2
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2,lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts = vertices.reshape((-1,1,2)) #nilai 2 untuk menunjukkan bahwa tiap titik dibuat 3 channel yang mewakili R, G, dan B
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %%
# Tugas
# no 1 (Red-Green)
img_rg = img.copy()
img_rg[:,:,2] = 0
plt.imshow(img_rg)

# %%
#no 1(Green-Blue)
img_gb = img
img_gb[:,:,0] = 0
plt.imshow(img_gb)

# %%
#no 2 
img_bk = img[10:100,10:100]
plt.imshow(img_bk)

# %%
#no 3
plt.imshow(img[5:30])

# %%
# no 4 
img_k = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cv.rectangle(img_k, pt1=(300,350), pt2=(50,160), color=(0,255,255), thickness=10)
cv.rectangle(img_k, pt1=(550,150), pt2=(650,200), color=(0,255,0),thickness=10)
cv.rectangle(img_k, pt1=(410,300), pt2=(500,350), color=(255,255,255),thickness=10)
cv.rectangle(img_k, pt1=(460,200), pt2=(540,310), color=(255,0,0),thickness=10)
cv.rectangle(img_k, pt1=(350,400), pt2=(500,350), color=(0,0,255),thickness=10)
plt.imshow(img_k)

# %%
# no 5
img_t = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize=(7,7))
ax = fig.add_subplot(111)
ax.imshow(img_t)

# %%
img_kitten = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img_kitten)

# %%
cv.circle(img_kitten,center=(400,180),radius=100,color=(255,0,0),thickness=8)
plt.imshow(img_kitten)

# %%
cv.rectangle(img_kitten,pt1=(250,50),pt2=(500,300),color=(0,0,255),thickness=15)
plt.imshow(img_kitten)

# %%
img_kitten = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
plt.imshow(img_kitten)

# %%
imgb = img_kitten
img_blue = cv.cvtColor(img_kitten, cv.COLOR_BGR2RGB) #konversi channel BGR -> RGB
plt.imshow(img_blue)

# %%
img = cv.imread('/content/drive/MyDrive/PCVK_MM/Images/kitten01.jpg')
img_rgb = cv.cvtColor(img,cv.COLOR_BGR2RGB)

img_arr = [img_rgb, img_rgb.copy(), img_rgb.copy()] 
title = ('R', 'G', 'B') 
# Create figure 
fig = plt.figure(figsize=(12, 6)) 
# setting values to rows and column variables 
rows = 1 
columns = 3 

for i in range(3): 
  if(i == 0): 
    img_arr[i][:,:,1] = 0 
    img_arr[i][:,:,2] = 0 
  elif(i == 1): 
    img_arr[i][:,:,0] = 0 
    img_arr[i][:,:,2] = 0 
  else: 
    img_arr[i][:,:,0] = 0 
    img_arr[i][:,:,1] = 0 
    cv.rectangle(img_arr[i], pt1=(0,500), pt2=(150,630), color=(0,0,255), thickness=-1) 
  fig.add_subplot(rows, columns, i+1) 
  plt.title(title[i]) 
  plt.imshow(img_arr[i])
